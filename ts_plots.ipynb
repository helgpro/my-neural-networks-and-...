# %%
import matplotlib.pyplot as plt
import numpy as np

x,y,yerr = rand(3,10)
errorbar(x, y, yerr, marker='s', mfc='red',
         mec='green', ms=20, mew=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e25d8b27b8f7> in <module>
#       2 import numpy as np
#       3
# ----> 4 x,y,yerr = rand(3,10)
#       5 errorbar(x, y, yerr, marker='s', mfc='red',
#       6          mec='green', ms=20, mew=4)
#
# NameError: name 'rand' is not defined

# %%
x = [1,2,3,4,5]
y = [1,1,2,1,3]
err = 0.5
plt.errorbar(x,y, yerr=err)

# %%
x = [1,2,3,4,5]
y = [1,1,2,1,3]
err = [0.1,0.2,0.1,1,0.4]
plt.errorbar(x,y, yerr=err,fmt=' ',color='black')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
x = [1,2,3,4,5]
y = [-1,1,2,1,-3]
err = [0.3,0.2,0.1,1,0.4]
plt.title("Simplest errorbars, 0.2 in x, 0.4 in y")
plt.errorbar(x,y, yerr=err,fmt='o',ecolor='black',capsize=4,ms=6)
plt.xlabel('Дата измерения')
# Out:
# Text(0.5, 0, 'Дата измерения')

# %%
from datetime import datetime, date, time
x = [1,2,3,4,5,6]
y = [-0.10,0.10,0.20,-0.20,-0.291,0.291]
p = np.polyfit(x,y,1)
print('p=',p)
# y2=p[0]*x+p[1]*x
y2 = np.polyval(p, x)
print(y2)

err = [0.3,0.2,0.4,0.1,0.1,0.2]

fig = plt.figure(figsize=(10,5))
d = [date(2009, 11, 18),date(2009,11,19),date(2009,11,21),date(2009,11,22),date(2009,11,24),date(2009,11,25),]
plt.title("Simplest errorbars, 0.2 in x, 0.4 in y")
plt.errorbar(d,y, yerr=err,fmt='o',ecolor='black',capsize=4,ms=6)
plt.errorbar(d,y,fmt='o',ecolor='black',capsize=4,ms=6)
plt.plot(d, y2, 'r')
plt.xlabel('Дата измерения')
# Out:
# p= [ 0.01091429 -0.0382    ]
# [-0.02728571 -0.01637143 -0.00545714  0.00545714  0.01637143  0.02728571]
# Text(0.5, 0, 'Дата измерения')

# %%
import matplotlib.cbook as cbook
from datetime import datetime, date, time
import matplotlib.dates as mdates
import numpy as np
import matplotlib.pyplot as plt

#with cbook.get_sample_data('goog.npz') as datafile:
#    r = np.load(datafile)['price_data'].view(np.recarray)

# Matplotlib prefers datetime instead of np.datetime64.
#date = r.date.astype('O')
d = date(2005, 7, 14),date(2005,7,15),date(2006,7,16)
fig, ax = plt.subplots()
ax.plot(d)
#ax.set_title('Default date handling can cause overlapping labels')

# %% [markdown]
# # kjkjdkjsd
# - hhjk
