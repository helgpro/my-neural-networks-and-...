# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('./titanic.csv',
                  index_col='PassengerId')
data.head(4)
data[(data['Embarked'] == 'C') & (data['Fare']>200).sort_values()]
#data[(data['Embarked'] == 'C') & (data.Fare > 200)].head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 119                 0       1
# 259                 1       1
# 300                 1       1
# 312                 1       1
# 378                 0       1
# 381                 1       1
# 558                 0       1
# 680                 1       1
# 701                 1       1
# 717                 1       1
# 738                 1       1
# 743                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 119                                   Baxter, Mr. Quigg Edmond    male  24.0
# 259                                           Ward, Miss. Anna  female  35.0
# 300            Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 312                                 Ryerson, Miss. Emily Borie  female  18.0
# 378                                  Widener, Mr. Harry Elkins    male  27.0
# ...

# %%
def age_category(age):
    if age <30: 
        return 1
    if age >55:
        return 2
    else:
        return 3
age_category = [age_category(age) for age in data.Age]    
data['agecat']=age_category
#arr = data['Age'].apply(age_category)
#data.Sex.lamda().count()
data['Sex'].value_counts()
#data.Fare.apply(np.max) 
#d = {'male' : 0, 'female' : 1}
#a=data['Sex'].map(d)
#data.groupby(['Sex'])['Age'].Fare([np.mean, np.std, np.min, np.max])
data[(data.Embarked=='P')]
data.Pclass.value_counts()
#claP =data['Sex'].apply(lambda female:'F' if female else 'm')
def clas_cat(cat):
    if cat ==1:
        return 'P'
    if cat == 2:
        return 'C'
    if cat == 3:
        return 'S'
    
clap=data['Pclass'].map(clas_cat)
data['strPclas'] =clap
#data
data.strPclas[(data['Sex']=='male')].count()
man2 = data[ (data.Pclass==2)]
man2['Sex'].value_counts()
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %%
pd.set_option('precision', 2)
data.Fare.std()
#data['Age'].apply(lambda age:age if age<30 else False)
#x = lambda x: x if x<=30 else False# аргумент, выражение     аргументы, что вернуть, условия, else что вернуть
mol =data['Survived'][(data['Sex']<='female')&(data['Survived']==1)].count()
star = data['Survived'][(data['Sex']>='female')&(data['Survived']==0)].count()
sred = mol+star
proc = mol*100/sred
proc1 = star*100/sred

data['Age'][(data['Sex']=='male')].mean()
# Out:
# 27.915708812260537

# %% [markdown]
# ## Выборка популяпности имен

# %%
#a = data.groupby(['Name','Sex'])['Name'].count()

m = data['all_names'] =  data['Name'].str.split(',').str[0]
#att = data['all_names'][(data['Sex']=='male')]
att = data['all_names'][(data['Sex']=='male')]
arr = data['Name'].value_counts().index

atr = data["Name"].str.split(',').str[0]
#data.groupby(['Sex', 'all_names'])['all_names'].count()#.nlargest(5)
#for i in att:   
    #ar.append(i.split(',')[0])
#    print(i)
from collections import Counter     
counts = Counter(atr)
counts.most_common(5)    

##   print(y)
    #if y[1]=>4:
     #   print(y[0])
#data.groupby('PassengerId').count()
#a =data['Name'].str.split(',').str[1]
# Out:
# [('Andersson', 9), ('Sage', 7), ('Johnson', 6), ('Panula', 6), ('Goodwin', 6)]

# %% [markdown]
# ## Graphic for kolich

# %%
#data['Age'].hist()
#sns.boxplot(data['Age'])
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000019B02320>,
# ...
#       dtype=object)

# %% [markdown]
# ## Cotegor

# %%
sns.countplot(data['Pclass'])

# %% [markdown]
# ### col-col

# %%
data.columns
feat = [f for f in data.columns if 'name' in f]
feat.append('Name')
feat

sns.pairplot(data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-559-6ab150c93b5f> in <module>
#       5
#       6 sns.pairplot(data)
# ----> 7 sns.qqplot(data['Age'])
#
# AttributeError: module 'seaborn' has no attribute 'qqplot'

# %%
a = np.random.normal(5,5,250)
b = np.random.rayleigh(5,250)

percs = np.linspace(0,100,21)
qn_a = np.percentile(a, percs)
qn_b = np.percentile(b, percs)

plt.plot(qn_a,qn_b, ls="", marker="o")

x = np.linspace(np.min((qn_a.min(),qn_b.min())), np.max((qn_a.max(),qn_b.max())))
plt.plot(x,x, color="k", ls="--")

plt.show()
